# %% [markdown]
# # 1. Выбор гомологичных белков

# %% [markdown]
# #### Я выбрала сначала Актин, цитоплазматический 1 для человека, мыши, курицы и лошади, но они оказались слишком похожими,поэтому ...получилось это:

# %%
from IPython.display import display
from PIL import Image

img = Image.open('actb.png.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=464x251>

# %% [markdown]
# #### Поэтому я выбрала рецептор эпидермального фактора роста EGFR_HUMAN(P00533), EGFR_MOUSE(Q01279), EGFR_CHICK(P13387), EGFR_MACMU(P55245)

# %% [markdown]
# # 2. Выравнивание последовательностей

# %% [markdown]
# #### Выравнивала с помощью CLUSTAL

# %%
img = Image.open('EGFR.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=605x143>

# %%
from Bio import Phylo

nwk_file = "tree (1).nwk"
tree = Phylo.read(nwk_file, "newick")
Phylo.draw(tree)
